# %%
pip install ydata-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_chicago = pd.read_csv(
    "/content/Food_Inspections_20240220.tsv",sep='\t'
)
df_chicago.head()
# Out:
#    Inspection ID                   DBA Name                   AKA Name  \
# 0        2589714  HARVARD ELEMENTARY SCHOOL  HARVARD ELEMENTARY SCHOOL
# 1        2589691               EARLE SCHOOL               EARLE SCHOOL
# 2        2589700                HACHI SUSHI                HACHI SUSHI
# 3        2589699                  Shoesmith                  Shoesmith
# 4        2589698     PETE'S FRESH MARKET #5        PETE'S FRESH MARKET
#
#    License #  Facility Type           Risk                   Address     City  \
# 0    23581.0         School  Risk 1 (High)    7525 S Harvard (332W)   CHICAGO
# 1  3399102.0         School  Risk 1 (High)  2040 W 62nd  (6200S) ST   CHICAGO
# 2  2636936.0     Restaurant  Risk 1 (High)          3448 E 118TH ST   CHICAGO
# 3    25371.0         School  Risk 1 (High)   1330 E 50th St (5000S)   CHICAGO
# 4  1598145.0  Grocery Store  Risk 1 (High)          3448 E 118TH ST   CHICAGO
#
# ...

# %%
df_dallas = pd.read_csv(
    "/content/Restaurant_and_Food_Establishment_Inspections__October_2016_to_Present__20240220.tsv",sep='\t'
)
df_chicago.head()
# Out:
# <ipython-input-14-acc7391dacec>:1: DtypeWarning: Columns (93,95,97,98,99,101,102,103,105,106,107,109,110) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_dallas = pd.read_csv(
#    Inspection ID                   DBA Name                   AKA Name  \
# 0        2589714  HARVARD ELEMENTARY SCHOOL  HARVARD ELEMENTARY SCHOOL
# 1        2589691               EARLE SCHOOL               EARLE SCHOOL
# 2        2589700                HACHI SUSHI                HACHI SUSHI
# 3        2589699                  Shoesmith                  Shoesmith
# 4        2589698     PETE'S FRESH MARKET #5        PETE'S FRESH MARKET
#
#    License #  Facility Type           Risk                   Address     City  \
# 0    23581.0         School  Risk 1 (High)    7525 S Harvard (332W)   CHICAGO
# 1  3399102.0         School  Risk 1 (High)  2040 W 62nd  (6200S) ST   CHICAGO
# 2  2636936.0     Restaurant  Risk 1 (High)          3448 E 118TH ST   CHICAGO
# ...

# %%
profile = ProfileReport(df_chicago, title="Chicago Restaurant Data")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile.to_file("Chicago Restaurant Data.html")
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile = ProfileReport(df_dallas, title="Dallas Restaurant Data")

# %%
profile

# %%
profile.to_file("Dallas Restaurant Data.html")
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
